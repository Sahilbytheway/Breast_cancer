# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilbytheway/Breast_cancer/blob/master/Breast_cancer_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import preprocessing



import warnings
warnings.filterwarnings('ignore')

# %%
# Read the file "data.csv" and print the contents.
data = pd.read_csv("data.csv")

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# To visually inspect the new data set. 
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
diag_gr = data.groupby('diagnosis', axis=0)
pd.DataFrame(diag_gr.size(), columns=['# of observations'])
# Out:
#            # of observations
# diagnosis
# B                        357
# M                        212

# %% [markdown]
# Observation:
# 357 observations indicating the absence of cancer cells and 212 show absence of cancer cell

# %%
#Malignant = 1 (indicates prescence of cancer cells)
#Benign = 0 (indicates abscence)
data.diagnosis.replace(to_replace=dict(B=0, M=1), inplace = True)

# %%
#Attribute corelation

# red suggests that attributes are correlated with each other. 
# yellow and green suggest some moderate correlation
# blue shows negative correlations.
from matplotlib import cm as cm

features_mean= list(data.columns[2:12])
plt.figure(figsize=(10,10))
sns.heatmap(data[features_mean].corr(), annot=True, square=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Obervation:**
# We can see strong positive relationship exists with mean values paramaters between 1-0.75;.

# %% [markdown]
# From the graph, it is understood that radius_mean, perimeter_mean, area_mean, concavity_mean and concave_points_mean are useful in predicting cancer type due to the distinct grouping between malignant and benign cancer. area_worst and perimeter_worst are also quite useful.

# %%
target=data.diagnosis
cancer=['radius_mean', 'perimeter_mean', 'area_mean', 'concavity_mean','concave points_mean','area_worst','perimeter_worst']
data2=data[cancer]
data2.head()
# Out:
#    radius_mean  perimeter_mean  area_mean  concavity_mean  \
# 0        17.99          122.80     1001.0          0.3001
# 1        20.57          132.90     1326.0          0.0869
# 2        19.69          130.00     1203.0          0.1974
# 3        11.42           77.58      386.1          0.2414
# 4        20.29          135.10     1297.0          0.1980
#
#    concave points_mean  area_worst  perimeter_worst
# 0              0.14710      2019.0           184.60
# 1              0.07017      1956.0           158.80
# 2              0.12790      1709.0           152.50
# 3              0.10520       567.7            98.87
# 4              0.10430      1575.0           152.20

# %%
svm = SVC()
svm.fit(data2, target)
Xnew = [[15.99, 102.80,1001,0.3501,0.28710,2019,164.60]]
prediction = svm.predict(Xnew)
if prediction[0] == '0':
  print("The cancer has been classified as benign.")
else:
  print("The cancer has been classified as malignant.")
# Out:
# The cancer has been classified as malignant.
